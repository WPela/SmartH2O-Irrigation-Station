# %% [markdown]
# <a href="https://colab.research.google.com/github/WPela/AIS_Arduino/blob/master/LinReg/Co2/LinReg_Coal_Co2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
xls = pd.ExcelFile('/content/drive/MyDrive/Python/Coal_CO2.xlsx')

# %%
df = pd.read_excel(xls, 'Final')
df.head()
# Out:
#    Year  Coal (Mt)  Co2 (Mt)
# 0  1990     187987      3568
# 1  1991     156866      3531
# 2  1992     128887      3414
# 3  1993     121034      3351
# 4  1994     103830      3340

# %%
x = df['Coal (Mt)']
y = df['Co2 (Mt)']

# %%
slope, intercept, r, p, std_err = stats.linregress(x, y)

# %%
def myfunc(x):
  return slope * x + intercept

# %%
r2 = r ** 2

# %%
mymodel = list(map(myfunc, x))

# %%
plt.scatter(x, y)
plt.plot(x, mymodel)
plt.title("Linear regression (Coal - Co2) | R^2 = " + str(round(r2, 4)) + " | p value = " + str(round(p, 4)))
plt.xlabel("Coal (Mt)")
plt.ylabel("Co2 (Mt)")
plt.show()

# %%
pred = myfunc(200000)
print(pred)
# Out:
# 3807.931393960524
